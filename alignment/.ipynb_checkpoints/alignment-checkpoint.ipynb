# %%
from __future__ import print_function

import glob
import cv2
import cv2
import numpy as np
import matplotlib.pyplot as plt

MAX_MATCHES = 500
GOOD_MATCH_PERCENT = 0.15

# %%
def get_images_list():
    images = []
    for file in glob.glob("./images/*.jpg"):
        images.append(file)
    return images

# %%
def alignImages(im1, im2):

    # Convert images to grayscale
    im1Gray = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY)
    im2Gray = cv2.cvtColor(im2, cv2.COLOR_BGR2GRAY)
  
    # Detect ORB features and compute descriptors.
    orb = cv2.ORB_create(MAX_MATCHES)
    keypoints1, descriptors1 = orb.detectAndCompute(im1Gray, None)
    keypoints2, descriptors2 = orb.detectAndCompute(im2Gray, None)
  
    # Match features.
    matcher = cv2.DescriptorMatcher_create(cv2.DESCRIPTOR_MATCHER_BRUTEFORCE_HAMMING)
    matches = matcher.match(descriptors1, descriptors2, None)# Sort matches by score
    matches.sort(key=lambda x: x.distance, reverse=False)
    
    # Remove not so good matches
    numGoodMatches = int(len(matches) * GOOD_MATCH_PERCENT)
    matches = matches[:numGoodMatches]
    # Draw top matches
    imMatches = cv2.drawMatches(im1, keypoints1, im2, keypoints2, matches, None)
    cv2.imwrite("matches.jpg", imMatches)
    
    # Extract location of good matches
    points1 = np.zeros((len(matches), 2), dtype=np.float32)
    points2 = np.zeros((len(matches), 2), dtype=np.float32)
    for i, match in enumerate(matches):
        points1[i, :] = keypoints1[match.queryIdx].pt
        points2[i, :] = keypoints2[match.trainIdx].pt
    
    # Find homography
    h, mask = cv2.findHomography(points1, points2, cv2.RANSAC)
    # Use homography
    height, width, channels = im2.shape
    im1Reg = cv2.warpPerspective(im1, h, (width, height))
    
    return im1Reg, h

# %%
images_list = get_images_list()

# %%
def compute_alignment(ref_image,source_image,outFilename="result3.jpg"):
    # ref image
    imReference = cv2.imread(ref_image, cv2.IMREAD_COLOR)
    # source image
    im = cv2.imread(source_image, cv2.IMREAD_COLOR)
    imReg, h = alignImages(im, imReference)
    
    cv2.imwrite(outFilename, imReg)
    
    return True

# %%
compute_alignment('./images/aligned2.jpg','./images/5.jpg')
# Out:
# True

# %% [markdown]
# ### Looking things granularly

# %%
img2 = cv2.imread('./images/aligned2.jpg', cv2.IMREAD_COLOR)
    # source image
img1 = cv2.imread('./images/5.jpg', cv2.IMREAD_COLOR)

# %%
img1.shape
# Out:
# (1539, 1231, 3)

# %%
def show_img(img):
    plt.figure(figsize = (20,15))
    plt.imshow(img,cmap='gray', vmin=0, vmax=255)

# %%
show_img(img1)

# %%
# Convert images to grayscale
im1Gray = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
im2Gray = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

# %%
im1Gray
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
show_img(im1Gray)

# %%
# Detect ORB features and compute descriptors.
orb = cv2.ORB_create(MAX_MATCHES)
keypoints1, descriptors1 = orb.detectAndCompute(im1Gray, None)
keypoints2, descriptors2 = orb.detectAndCompute(im2Gray, None)

# %%
descriptors1
# Out:
# array([[ 50,   0, 244, ..., 168,  81, 137],
#        [190,  57, 118, ..., 141,  83, 221],
#        [137,  70, 156, ..., 220,  93,  76],
#        ...,
#        [  7,  80, 151, ..., 124,  33,  85],
#        [ 34, 180, 224, ...,  12,  86, 222],
#        [ 98, 118,  71, ...,  94,  84, 127]], dtype=uint8)

# %%
# Match features.
matcher = cv2.DescriptorMatcher_create(cv2.DESCRIPTOR_MATCHER_BRUTEFORCE_HAMMING)
matches = matcher.match(descriptors1, descriptors2, None)# Sort matches by score
matches.sort(key=lambda x: x.distance, reverse=False)

# %%
len(matches)
# Out:
# 500

# %%
# Remove not so good matches
numGoodMatches = int(len(matches) * GOOD_MATCH_PERCENT)
matches = matches[:numGoodMatches]

# %%
# Extract location of good matches
points1 = np.zeros((len(matches), 2), dtype=np.float32)
points2 = np.zeros((len(matches), 2), dtype=np.float32)
for i, match in enumerate(matches):
    points1[i, :] = keypoints1[match.queryIdx].pt
    points2[i, :] = keypoints2[match.trainIdx].pt

# %%
points1.shape
# Out:
# (75, 2)

# %%
# Find homography
h, mask = cv2.findHomography(points1, points2, cv2.RANSAC)

# %%
mask.shape
# Out:
# (75, 1)

# %%
warp_matrix = np.eye(2, 3, dtype=np.float32)
warp_matrix2 = np.eye(3, 3, dtype=np.float32)

# %%
# Use homography
def apply_euclidean(img,h):
    height, width, channels = img.shape
    img_homographed = cv2.warpAffine(img, h, (width, height), flags=cv2.INTER_LINEAR + cv2.WARP_INVERSE_MAP)
    return img_homographed

# %%
# Use homography
def apply_homography(img,h):
    height, width, channels = img.shape
    img_homographed = cv2.warpPerspective(img, h, (width, height))
    return img_homographed

# %%
show_img(apply_euclidean(img1,warp_matrix))

# %%
M = cv2.getRotationMatrix2D((0, 0), 90, 1)
M
# Out:
# array([[ 6.123234e-17,  1.000000e+00,  0.000000e+00],
#        [-1.000000e+00,  6.123234e-17,  0.000000e+00]])

# %%
def rotate_image(img,angle):
    # openCV
    M = cv2.getRotationMatrix2D((0, 0), angle, 1)
    height, width, channels = img.shape
    result = cv2.warpAffine(img, M, (width, height))
    return result

# %%
show_img(img1)

# %%
show_img(rotate_image(img1))

# %%
import numpy as np
import cv2
import math
from scipy import ndimage

img_before = cv2.imread('./images/5.jpg')

cv2.imshow("Before", img_before)    
key = cv2.waitKey(0)

img_gray = cv2.cvtColor(img_before, cv2.COLOR_BGR2GRAY)
img_edges = cv2.Canny(img_gray, 100, 100, apertureSize=3)
lines = cv2.HoughLinesP(img_edges, 1, math.pi / 180.0, 100, minLineLength=100, maxLineGap=5)

angles = []

for x1, y1, x2, y2 in lines[0]:
    cv2.line(img_before, (x1, y1), (x2, y2), (255, 0, 0), 3)
    angle = math.degrees(math.atan2(y2 - y1, x2 - x1))
    angles.append(angle)

median_angle = np.median(angles)
img_rotated = ndimage.rotate(img_before, median_angle)

print("Angle is {}".format(median_angle))
cv2.imwrite('rotated.jpg', img_rotated)  
c2.imshow("after",img_rotated)
key = cv2.waitKey(0)
